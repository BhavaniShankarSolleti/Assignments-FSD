# %% [markdown]
# Q1. Creating and Dropping Database & Collection
#
# Ans:
#
# 1. Create a new MongoDB database named "PWSKILLS".
#
# *  Sol: USE PWSKILLS
# * This command will create the database named "PWSKILLS" and we are currently using that database now if we use this command.
# * If the database named with "PWSKILLS" is already present then we will using it right away, else it is created.
#
# 2. Create a collection named "Employees" within the "PWSKILLS" database.
#
# * Sol:
#     * use PWSKILLS
#     * db.createCollection("Employees")
# * By using first command we are in "PWSKILLS" databse and because of second ommand  "Employees" collection is created in "PWSKILLS".
#
# 3. Insert several documents representing employees into the "Employees" collection.
#
# * Sol:
#     * use PWSKILLS
#     * db.Employees.insertMany([{
#       id:1,name:"sham",age:34
#     },{id:2,name:"shankar",age:54},{id:3,name:"bhavani",age:68}])
#
# * The aboves set of commands inserts documents of 3 employees
# 4. Retrieve and display all documents from the "Employees" collection.
#
# * Sol:
#     * use PWSKILLS
#     * db.Employees.find()
# * The above set of commands displays all the documnets of employees.
# 5. Drop the "Employees" collection.
#
# * Sol:
#     * db.Employees.drop()
# * Drops the Employee collection.
#
# 6. Drop the "PWSKILLS" database.
#
# * Sol:
#     * use PWSKILLS
#     * db.dropDatabase()
#
#
# Q2. Insert a new document representing a customer into the "Customers" collection.
#
# sol:
# * use onlinestore
# * db.createCollection("customers")
# * db.customers.insertOne({name:"ram",age:27,email:"xyz@gmail.com",purchases:["butter","ghee","milk"])
#
# Q3.Retrieve and display all documents from the "Customers" collection.
#
# Sol:
# * use onlinestore
# * db.customers.find().pretty()
#
# * The above set of commands displays all the documents in pretty format  means with indentation to look better that to happens in shell only.
#
# Q4. Update the address of a specific customer.
#
# sol:
# * use onlinestore
# * db.customers.updateOne({name:"shankar"},{$set:{address:"sanfrancisco"}})
#
# Q5. Query for customers who have made purchases over a certain amount.
#
# Sol:
#
# * use onlinestore
# * db.customers.find({purchases:{$gt:5000})
#
# Q6. Remove a customer from the "Customers" collection.
#
# * use online store
# * db.customers.deleteOne({name:"shankar})
#
# Q7. Create a new database named "SchoolDB".
#
# Sol:
# * use SchoolDB
#
# Q8. Insert documents into the "Students" collection with fields like name, age, and grade.
#
# * use SchoolDB
# * db.createCollection("students")
# * db.students.insertMany({name:"sam",age:21,grade:"z"},{name:"ram",age:22,grade:"A"},{name:"suman',age:24,grade:"c"})
#
# Q9. Query for students older than a specific age or belonging to a particular grade.
#
# Sol:
#
# * use SchoolDB
# * db.students.find($or:[{age:{$gt:15},{grade:"A"})
#
# Q10.  Update the grade of a specific student in the "Students" collection.
#
# Sol:
# * use SchoolDB
# * db.students.updateOne({name:"kranti"},{$set :{grade:"E"}})
#
# Q11. Insert documents into the "Teachers" collection representing teachers with fields like name, subject, and
# experience.
#
# Sol:
#
# * use SchoolDB
# * db.createCollection("Teachers")
# * db.Teachers.insertMany({name:"uma",subject:"physics",experience:5},{name:"rama",subject:"maths",experience:7}.{name:"suma",subject:"biology",experience:10}
#
# Q12. Query for teachers specializing in a specific subject or with more than a certain amount of experience.
#
# Sol:
#
# * use SchoolDB
# * db.Teachers.find($or:[{subject:"physics"},{experience:{$gt:5}]
#
#
# Q13. Update the experience of a specific teacher in the "Teachers" collection.
#
# sol:
#
# * use SchoolDB
# * db.Teachers.updateOne({name:"uma"},{$set:{experience:20}})

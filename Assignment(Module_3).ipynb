# %% [markdown]
# 1. Build a simple webpage that defines that displays text as shown in the below image
# ![HTML sample question.png](data:image/png;base64,...)

# %%
<!DOCTYPE html>

<html>
<head>
</head>
<body>
 <!--Differt styles of text-->
 <p style = "font-size : 30px;">
  <b> The text will be bolded </b>
  <br>
  <i> The text will be italic </i>
  <br>
  <u> The will be underlined </u>
  <br>
  <mark> The text will be highlighted</mark>
  <br>
  <span> This is normal text <sup> This text is superscripted </sup> This is normal text again</span>
  <br>
  <span> This is normal text <sub> This text is subscripted </sub> This is normal text again </span>
  <br>
  <span> This is noraml text <small> this is small text </small> This is normal again</span>
  <br>
  <Strike> striked text</Strike>
  </p>

</body>
</html>

# %% [markdown]
# 2. Build a simple web age that helps users navigate different web development related websites. Note on clicking the hyperlink, the web page should open in new tab.

# %%
<!DOCTYPE html>
<html>
<body>

<!-- to navigate to different websites-->

   <div>
    <nav>
     Take me to
     <a href = " https://pwskills.com/course/full-stack-web-development-course/?source=pwskills.com&position=course_dropdown&from=home_page" target ="_blank"> PWSKILLS </a>
     to buy a course
     <br>
     Take me to
     <a href = " https://developer.mozilla.org/en-US/docs/Learn_web_development/Core/Structuring_content" target = "_blank"> MDN DOCS </a>
     to know more about web development
     <br>
     Take me to
     <a href =" https://pwskills.com/ " target = "_blank"> PW SKILLS LAB </a>
     to code
     <nav>
   </div>

</body>
</html>

# %% [markdown]
# 3.Build a simple blog web page with 3 pages home, web development, and web design. Each page must
# contain hyperlinks to other pages in the top, a heading of the page topic and a paragraph of information.
# For the home page you can add some information about yourself.

# %%
<!--homepage for blog-->
<!DOCTYPE html>
<html>
<body>
    <div>
        <h1> Home page </h1>
            <a href = " file:///Users/solletibhavanishankar/Desktop/Desktop%20-%20Solleti%E2%80%99s%20MacBook%20Air/HTML/webdevelopment.html" > -> Web Development </a>
            <br>
            <a href = "file:///Users/solletibhavanishankar/Desktop/Desktop%20-%20Solleti%E2%80%99s%20MacBook%20Air/HTML/webdesign.html" > -> web Design </a>
    </div>

    <div>

       <b> Name </b>     : Solleti Bhavanishankar<br>
       <b> Gmail id </b> : bhavanishankar2731@gmail.com<br>
       <b> Mobile No </b>: 7337049053<br>
       <b> Purchased courses</b>: <a href = " file:///Users/solletibhavanishankar/Desktop/Desktop%20-%20Solleti%E2%80%99s%20MacBook%20Air/HTML/webdevelopment.html" > Web Development </a>
       <br>
       <a href = "file:///Users/solletibhavanishankar/Desktop/Desktop%20-%20Solleti%E2%80%99s%20MacBook%20Air/HTML/webdesign.html"> web Design </a>


    </div>
</body>
</html>

# %%
<!--code for web development page-->
<!DOCTYPE html>
<html>
    <body>

        <a href ="file:///Users/solletibhavanishankar/Desktop/Desktop%20-%20Solleti%E2%80%99s%20MacBook%20Air/HTML/Homepage.html "> link to home page </a>
        <br>
        <a href =" file:///Users/solletibhavanishankar/Desktop/Desktop%20-%20Solleti%E2%80%99s%20MacBook%20Air/HTML/webdesign.html ">link to web design</a>
        <h1> Web Development</h1>
        <p>This page contain all inforamtion related to web development </p>

    </body>
</html>

# %%
<!-- code for web design page-->
<!DOCTYPE html>
<html>
    <body>
        <a href ="file:///Users/solletibhavanishankar/Desktop/Desktop%20-%20Solleti%E2%80%99s%20MacBook%20Air/HTML/Homepage.html "> link to home page </a>
        <br>
        <a href =" file:///Users/solletibhavanishankar/Desktop/Desktop%20-%20Solleti%E2%80%99s%20MacBook%20Air/HTML/webdevelopment.html ">link to web development</a>
        <h1> Web design course</h1>
        <p>This page contain all inforamtion related to web design</p>

    </body>
</html>

# %% [markdown]
# 4. Create an ordered list of HTML tags. Each list item must include the tag name and some information about
# the tag ?

# %%
<!DOCTYPE html>
<html>
    <body>
        <h2>  List of html tags along with their meaning </h2>
        <main>
            <ol>
                <li> Basic structure tags: </li>
                <ul style = " list-style-type: square; ">
                   <li> &lt; html &gt; -- Root element of an html document</li>
                   <li> &lt; head &gt; -- contains metadata like links, title, scripts</li>
                   <li> &lt; title &gt; -- Sets the title of the web page </li>
                   <li> &lt; body &gt; -- Contains the visible page content </li>
                </ul>

                <li> Heading and Text Tags: </li>
                <ul style = " list-style-type: square; ">
                    <li> &lt; h1 to h6 &gt; -- Headings from largest size to smallest size </li>
                    <li> &lt; p &gt; -- used for paragraph text </li>
                    <li> &lt; br &gt; -- line break(self closing tag ) </li>
                    <li> &lt; hr &gt; -- Horixontal rule ( a thematic break ) </li>
                    <li> &lt; span &gt; -- inline cotainer for text </li>
                    <li> &lt; div &gt; -- Block level container </li>
                 </ul>

                <li> Formatting Tags:</li>
                <ul style = " list-style-type: square; ">
                    <li> &lt; b &gt; -- bold text tag </li>
                    <li> &lt; strong &gt; -- Important( bold ) text </li>
                    <li> &lt; i &gt; -- italic text  </li>
                    <li> &lt; em  &gt; -- Emphasized text </li>
                    <li> &lt; u &gt; -- Underlined text </li>
                    <li> &lt; mark &gt; -- Highlighted text </li>
                    <li> &lt; small &gt -- small text </li>
                    <li>&lt; sub &gt -- Subscripted text</li>
                    <li>&lt; sup &gt -- Superscripted text</li>
                    <li>&lt; del &gt -- deleted( strikethrough) text</li>
                    <li>&lt; ins &gt -- inserted (underlined) text</li>
                    <li>&lt; pre &gt -- preformatted text(Preserves white spaces and line breaks)</li>
                    <li>&lt; sub &gt -- Subscripted text</li>

                </ul>

                <li> Lists Tags:</li>
                <ul style = " list-style-type: square; ">
                    <li> &lt; ul &gt; -- Unordered list </li>
                    <li> &lt; ol &gt; -- Ordered list </li>
                    <li> &lt; li &gt; -- list item </li>
                    <li> &lt; dl &gt; -- Description list </li>
                    <li> &lt; dt &gt -- Term in a description item </li>
                    <li> &lt; dd &gt -- Description of description list</li>
                 </ul>


                <li> Links and media: </li>
                <ul style = " list-style-type: square; ">
                    <li> &lt; a &gt; -- Achor tag used to insert the hyperlink so that we can redirect another webpage</li>
                    <li> &lt; img &gt; --  used to insert image </li>
                    <li> &lt; audio &gt; -- Used to insert audio file </li>
                    <li> &lt; video  &gt; -- used to insert video file </li>
                    <li> &lt; source &gt; -- source for audio or video </li>
                    <li> &lt; iframe &gt; -- inline frame (embed external content)</li>
                </ul>


                <li> Table tags: </li>
                <ul style = " list-style-type: square; ">
                    <li> &lt; table &gt; -- Table container </li>
                    <li> &lt; tr &gt; -- table row </li>
                    <li> &lt; td &gt; -- Table data cell </li>
                    <li> &lt; th &gt; -- Table header cell</li>
                    <li> &lt; thead &gt; -- Table head section </li>
                    <li> &lt; tbody &gt; -- Table body section </li>
                    <li> &lt; tfoot &gt; -- Table footer section </li>
                    <li> &lt; caption &gt; -- Table caption </li>
                 </ul>


                <li> Forms and input tags: </li>
                <ul style = " list-style-type: square; ">
                    <li> &lt; form &gt; -- form container </li>
                    <li> &lt; input &gt; -- input field(text, password, radio, checkbox, etc.) </li>
                    <li> &lt; textarea &gt; -- Multiline input text </li>
                    <li> &lt; buttton &gt; -- Used to create clickable button</li>
                    <li> &lt; select &gt; -- Dropdown list </li>
                    <li> &lt; option &gt; --  option in dropdown list </li>
                    <li> &lt; label  &gt; -- label for form elements </li>
                    <li> &lt; fieldset &gt; -- group related form elements </li>
                    <li> &lt; legend &gt; -- Title for field set </li>
                 </ul>

                <li> Semantic and Structural tags: </li>
                <ul style = " list-style-type: square; ">
                    <li> &lt; header &gt; --  page or section header </li>
                    <li> &lt; footer &gt; -- Page or section footer </li>
                    <li> &lt; nav &gt; -- navigation links </li>
                    <li> &lt; article &gt; --  Independent, self-contained content </li>
                    <li> &lt; section &gt; -- Themantic( connected with the subject) grouping of content</li>
                    <li> &lt; aside &gt; -- sidebar content</li>
                    <li> &lt; main &gt; -- Mian content area </li>
                    <li> &lt; figure &gt; -- Image, diagram, or visual content </li>
                    <li> &lt; figcaption &gt; -- Caption for a figure</li>
                 </ul>

                <li> Metadata Tags: </li>
                <ul style = " list-style-type: square; ">
                    <li> &lt; meta &gt; -- Metadata (like character set, viewport settings) </li>
                    <li> &lt; link  &gt; -- External resources (like stylesheets) </li>
                    <li> &lt; style &gt; --  Internal css styles </li>
                    <li> &lt; script &gt; --  javascript code</li>

                 </ul>

                <li>  Interactive and Other tags: </li>
                <ul style = " list-style-type: square; ">
                    <li> &lt; details &gt; -- Interactive disclosure widget </li>
                    <li> &lt; summary &gt; -- summary for the &lt;details&gt; tag </li>
                    <li> &lt; Dailog  &gt; -- Modal dailog box </li>
                    <li> &lt; Progress &gt; --  Progress bar </li>
                    <li> &lt; meter &gt; -- Measurment within a known range</li>
                 </ul>


            </ol>
        </main>
    </body>
</html

# %% [markdown]
# 5. Creata a description list of full stack web development tech stack using the dl tag.Each term should be a tech stack name and description should be a breif explanation of what the tech stack is used for ?

# %%
<!--html code for techstack with breif info on each stack-->
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <h2>Tech stack for Full Stack web development</h2>
    <p>Below text contains different technologies and their breif intro</p>
    <main>
    <dl>

        <dt> <Strong>mongo database<Strong></dt>

        <dd>It's a NoSql database, instead of using tables it stores data in Json format, its a schemaless means field and data types can vary from document to document.</dl>

        <dt><Strong>Express<Strong></dt>

        <dd>It's a web application framework for node.js, simplifies server side development like handling requests, routes, middleware, great for creating REpresentational state transfer API's quickly.</dd>

        <dt><Strong>react.js</Strong></dt>

        <dd>It's a javascript frontend library for buiding user interfaces, breaks UI into reusable components like (buttons, forms), useful for superfast rendering by  updating what changes in webpage. </dd>

        <dt><strong>Node.js</strong></dt>

        <dd>It's backend javscript runtime environment, uses chrome v8 engine which is super fast, used to build server side logic,API's and file system access,handles many request's simultaneously without waiting. </dd>

    </dl>
    </main>
</body>
</html>

# %% [markdown]
# 6. Create an ordered list of the full stack web development tech stack HTML, CSS, and JS. For each tech
# stack, create a table that lists the tech stack name, its primary use cases, and some key features or
# benefits.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
     <h2> Table representation of tech stack along with their primary usecase and keyfeatures </h2>
     <ol>
        <li><h3>HTML</h3></li>
           <Table border = " 1 ">
            <tr>
                <td> Primary Usecases </td>
                <td> Key features & benefits </td>
            </tr>
            <tr>
                <td> Used to build the structure of web pages</td>
                <td>
                   <ul>
                       <li> Defines the structure and content of web pages using a simple, tag-based syntax </li>
                       <li> Supports text, images, links, forms, tables, and multimedia elements </li>
                       <li> Provides semantic elements for better accessibility and SEO </li>
                   </ul>
                </td>
            </tr>
           </Table>
        <li><h3>CSS</h3></li>
        <Table border = " 1 ">
            <tr>
                <td> Primary Usecases </td>
                <td> Key features & benefits </td>
            </tr>
            <tr>
                <td> Used to styele the elements in webpage </td>
                <td>
                   <ul>
                       <li> Controls the visual presentation and layout of HTML elements </li>
                       <li> Uses selectors, properties, and values to style fonts, colors, spacing, and positioning </li>
                       <li> Supports responsive design with media queries and flexible box/grid models </li>
                   </ul>
                </td>
            </tr>
           </Table>
        <li><h3>JavaScript</h3></li>
        <Table border = " 1 ">
            <tr>
                <td> Primary Usecases </td>
                <td> Key features & benefits </td>
            </tr>
            <tr>
                <td> Adds interactivity to the webpage </td>
                <td>
                   <ul>
                       <li> Adds interactivity and dynamic behavior to web pages  </li>
                       <li> Manipulates HTML and CSS via the DOM (Document Object Model) </li>
                       <li> Supports client-side logic, event handling, and asynchronous programming </li>
                   </ul>
                </td>
            </tr>
           </Table>

     </ol>


</body>
</html>

# %% [markdown]
# 7. Build a complex nested list structure representing a multi-level table of contents. Use unordered lists
# 'ul" and list items "li" with inline-block styling to create a structured layout. Apply formatting tags to
# enhance the presentation of list items.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <h2>Table of Contents</h2>
    <aside>
    <div>
             <ul>
                <li> <u> Part 1: Introduction </u> </li>
                <li> <u> Part 2: Getting started </u> <li>
                      <ul>
                        <li> <u> 2.1 Installing the software </u></li>
                        <li> <u> 2.2 Creating a new project </u></li>
                            <ul>
                                <li><u> 2.2.1 Project Tempaltes</u><li>
                                <li><u> 2.2.2 Customizing settings </u></li>
                            </ul>
                        <li><u> 2.3 Exploring the interface </u></li>
                           <ul>
                            <li><u>2.3.1 Toolbar features</u></li>
                            <li><u>2.3.2 Panel Layout</u></li>
                                <ul>
                                    <li><u> 2.3.2.1 Docking panels </u></li>
                                    <li><u> 2.3.2.2 Tabbed Interfaces </u></li>
                                </ul>
                            </ul>
                         </ul>
                <li><u>Part 3: Advanced Topics</u></li>
                    <ul>
                        <li><u>3.1 Working with plugins </u></li>
                           <ul>
                              <li><u> 3.1.1 Installing plugins</u></li>
                              <li><u> 3.1.2 Plugin configuration</u></li>
                           </ul>
                        <li><u>3.2 Customizing the UI</u></li>
                            <ul>
                                <li><u>3.2.1 Changing Themes </u></li>
                                <li><u>3.2.2 Configuting shortcuts </u></li>
                            </ul>
                        <li><u>3.3 Optimizing performance</u></li>
                            <ul>
                                <li><u>3.3.1 Caching Strategies</u></li>
                                <li><u>3.3.2 Resource minification</u></li>
                            </ul>
                    </ul>
                <li><u>part 4: Conclusion</u></li>
        </ul>
    </div>
    </aside>
</body>
</html>

# %% [markdown]
# 8. Create a table to display a conference schedule. Each row corresponds to a time slot, and each column
# corresponds to a room. Some time slots might have multiple sessions running simultaneously in different
# rooms. Utilize rowspan and colspan attributes as necessary to accommodate this complex schedule.
# (use table attribute “cellpadding”  to give extra padding in each table cell ).

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <span>
        <h2>conference schedule</h2>
    </span>
    <br>
    <div>
        <table border = "1" >
            <tr>
                <td> Time</td>
                <td> Room 1 </td>
                <td> Room 2 </td>
                <td> Room 3 </td>
                <td> Romm 4 </td>
            </tr>

            <tr>
                <td rowspan = " 3 "> 9:00 AM - 10:00 PM </td>
                <td rowspan = " 2 "> Keynote </td>
                <td> Session A </td>
                <td> Session B </td>
                <td rowspan = " 3 "> Session c </td>
            </tr>

            <tr>
                <td> Session D </td>
                <td> Session E </td>
            </tr>

            <tr>
                <td > 10:00 AM - 11:00 AM </td>
                <td colspan = " 2 "> Session F </td>
            </tr>

            <tr>
                <td > 12:00 PM - 1:00 PM </td>
                <td colspan = " 4 "> Lunch break </td>
            </tr>
            <tr>
                <td rowspan = " 2 ">1:PM - 2:00PM</td>
                <td> Session G </td>
                <td rowspan = " 2 "> Session H </td>
                <td> Session I </td>
                <td> Session J </td>
            </tr>

            <tr>
                <td> Session K </td>
                <td> Session L </td>
                <td> Session M </td>
            </tr>
        </table>

    </div>
</body>
</html>
